# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip3 install mediapipe opencv-python pandas scikit-learn

# %%
# !pip3 install mediapipe

# %%
import pandas
import numpy
import mediapipe
import tensorflow

print(f"Pandas Version: {pandas.__version__}")
print(f"NumPy Version: {numpy.__version__}")
print(f"Mediapipe Version: {mediapipe.__version__}")
print(f"Tensorflow Version: {tensorflow.__version__}")
# Out:
# Pandas Version: 2.2.3
# NumPy Version: 1.26.4
# Mediapipe Version: 0.10.21
# Tensorflow Version: 2.18.0

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_hands = mp.solutions.hands
mp_face_mesh = mp.solutions.face_mesh  # ใช้ Face Mesh โดยตรง

# ใช้ Face Mesh สำหรับ Face Landmarks
FACE_CONNECTIONS = mp_face_mesh.FACEMESH_TESSELATION
HAND_CONNECTIONS = mp_hands.HAND_CONNECTIONS
POSE_CONNECTIONS = mp_holistic.POSE_CONNECTIONS

cap = cv2.VideoCapture(0)

with mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5) as face_mesh, \
     mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        

        # ประมวลผล Holistic Model
        results = holistic.process(image)

        # ประมวลผล Face Mesh
        face_results = face_mesh.process(image)

        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # 1. Face landmarks (ใช้ Face Mesh โดยตรง)
        if face_results.multi_face_landmarks:
            for face_landmarks in face_results.multi_face_landmarks:
                mp_drawing.draw_landmarks(image, face_landmarks, FACE_CONNECTIONS, 
                                          mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                          mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1))

        # 2. Right Hand
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, HAND_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))

        # 3. Left Hand
        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, HAND_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))

        # 4. Pose Detections
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, POSE_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

        cv2.imshow('Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1743272223.460991 5243749 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1743272223.465101 5277541 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1743272223.469246 5277545 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1743272223.483329 5243749 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1743272223.570581 5277555 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1743272223.586367 5277556 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
results.face_landmarks.landmark[0].x
# Out:
# 0.5518408417701721

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <!--<img src="https://i.imgur.com/AzKNp7A.png">-->

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks[-5]
# Out:
# 'v500'

# %%
with open('newdata.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Happy"

# %%
class_name = "Sad"

# %%
class_name = "Victorious"

# %%
class_name = "Crying"

# %%
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_hands = mp.solutions.hands
mp_face_mesh = mp.solutions.face_mesh  # ใช้ Face Mesh โดยตรง

# ใช้ Face Mesh สำหรับ Face Landmarks
FACE_CONNECTIONS = mp_face_mesh.FACEMESH_TESSELATION
HAND_CONNECTIONS = mp_hands.HAND_CONNECTIONS
POSE_CONNECTIONS = mp_holistic.POSE_CONNECTIONS

cap = cv2.VideoCapture(0)

with mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5) as face_mesh, \
     mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        

        # ประมวลผล Holistic Model
        results = holistic.process(image)

        # ประมวลผล Face Mesh
        face_results = face_mesh.process(image)

        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # 1. Face landmarks (ใช้ Face Mesh โดยตรง)
        if face_results.multi_face_landmarks:
            for face_landmarks in face_results.multi_face_landmarks:
                mp_drawing.draw_landmarks(image, face_landmarks, FACE_CONNECTIONS, 
                                          mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                          mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1))

        # 2. Right Hand
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, HAND_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))

        # 3. Left Hand
        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, HAND_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))

        # 4. Pose Detections
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, POSE_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))
            
        #  Export coordinates to CSV
        try:
            # Extract pose  landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            # Extract face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            # Concatenate the rows
            row = pose_row+face_row

            # Append class name
            row.insert(0, class_name)

            # Export to CSV
            with open('newdata.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)



        except:
            pass

        cv2.imshow('Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1743273620.436967 5243749 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1743273620.439947 5309513 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1743273620.448995 5309512 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1743273620.465252 5243749 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1743273620.545695 5309524 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1743273620.559834 5309523 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('newdata.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  Happy  0.556560  0.510065 -0.899893  0.999821  0.576864  0.454289
# 1  Happy  0.553979  0.509854 -0.900353  0.999819  0.576182  0.453227
# 2  Happy  0.552362  0.509617 -0.900228  0.999816  0.575590  0.452407
# 3  Happy  0.550539  0.509563 -0.907674  0.999812  0.574842  0.452009
# 4  Happy  0.549768  0.509446 -0.919379  0.999807  0.574600  0.451603
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.850692  0.999513  0.588263  ... -0.002629   0.0  0.609531  0.455748
# 1 -0.850588  0.999512  0.588163  ... -0.003368   0.0  0.608431  0.453894
# 2 -0.849632  0.999506  0.588046  ... -0.002997   0.0  0.609035  0.453780
# 3 -0.855190  0.999498  0.587828  ... -0.003060   0.0  0.608821  0.454352
# 4 -0.864510  0.999487  0.587778  ... -0.002472   0.0  0.608774  0.454985
#
#        z500  v500      x501      y501      z501  v501
# 0  0.017528   0.0  0.613633  0.449575  0.018383   0.0
# ...

# %%
df.tail()
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 1120  Crying  0.524376  0.583756 -1.115184  0.999895  0.550384  0.504291
# 1121  Crying  0.522336  0.581297 -0.973613  0.999876  0.548792  0.502468
# 1122  Crying  0.521599  0.570071 -0.977505  0.999875  0.547507  0.492844
# 1123  Crying  0.521873  0.558028 -1.085793  0.999870  0.547365  0.481933
# 1124  Crying  0.521676  0.552647 -1.030313  0.999868  0.546823  0.472222
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# 1120 -1.063704  0.999867  0.564843  ... -0.011764   0.0  0.578959  0.499393
# 1121 -0.922309  0.999830  0.563571  ... -0.010401   0.0  0.577510  0.492725
# 1122 -0.926822  0.999814  0.562274  ... -0.008942   0.0  0.578353  0.481989
# 1123 -1.034351  0.999790  0.562156  ... -0.009371   0.0  0.578478  0.472412
# 1124 -0.980162  0.999774  0.561590  ... -0.009306   0.0  0.578175  0.463758
#
#           z500  v500      x501      y501      z501  v501
# ...

# %%
df[df['class']=='Sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 206   Sad  0.545385  0.569954 -0.807821  0.999855  0.577400  0.487993
# 207   Sad  0.546338  0.570987 -0.976578  0.999858  0.577971  0.488728
# 208   Sad  0.548639  0.571737 -1.003629  0.999862  0.579301  0.489529
# 209   Sad  0.550349  0.572491 -1.034195  0.999865  0.581039  0.490310
# 210   Sad  0.551643  0.573682 -1.113725  0.999864  0.582478  0.491341
# ..    ...       ...       ...       ...       ...       ...       ...
# 564   Sad  0.549727  0.591598 -1.092749  0.999733  0.579776  0.508696
# 565   Sad  0.548145  0.591638 -1.109852  0.999735  0.578089  0.508651
# 566   Sad  0.547526  0.591637 -1.117945  0.999733  0.577474  0.508563
# 567   Sad  0.546991  0.591543 -1.114926  0.999735  0.576660  0.508383
# 568   Sad  0.546915  0.591197 -1.113804  0.999738  0.576235  0.507687
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
df[df['class']=='Victorious']
# Out:
#           class        x1        y1        z1        v1        x2        y2  \
# 569  Victorious  0.577353  0.597197 -1.024037  0.999986  0.596327  0.541554
# 570  Victorious  0.577416  0.601834 -1.023699  0.999984  0.596267  0.545103
# 571  Victorious  0.577241  0.604711 -0.897111  0.999983  0.596048  0.547694
# 572  Victorious  0.577202  0.606237 -0.792988  0.999982  0.596145  0.549392
# 573  Victorious  0.576837  0.612675 -0.657981  0.999982  0.595894  0.555048
# ..          ...       ...       ...       ...       ...       ...       ...
# 899  Victorious  0.516263  0.548848 -0.884186  0.999985  0.536729  0.473984
# 900  Victorious  0.514390  0.543898 -0.840664  0.999978  0.536323  0.470120
# 901  Victorious  0.515154  0.539401 -0.889148  0.999971  0.536501  0.465525
# 902  Victorious  0.515032  0.529745 -0.884848  0.999947  0.536757  0.458699
# 903  Victorious  0.514857  0.527628 -0.860542  0.999931  0.536803  0.457162
#
# ...

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 902     Victorious
# 867     Victorious
# 1056        Crying
# 888     Victorious
# 272            Sad
#            ...
# 387            Sad
# 328            Sad
# 535            Sad
# 892     Victorious
# 741     Victorious
# Name: class, Length: 338, dtype: object

# %%
df
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 0      Happy  0.556560  0.510065 -0.899893  0.999821  0.576864  0.454289
# 1      Happy  0.553979  0.509854 -0.900353  0.999819  0.576182  0.453227
# 2      Happy  0.552362  0.509617 -0.900228  0.999816  0.575590  0.452407
# 3      Happy  0.550539  0.509563 -0.907674  0.999812  0.574842  0.452009
# 4      Happy  0.549768  0.509446 -0.919379  0.999807  0.574600  0.451603
# ...      ...       ...       ...       ...       ...       ...       ...
# 1120  Crying  0.524376  0.583756 -1.115184  0.999895  0.550384  0.504291
# 1121  Crying  0.522336  0.581297 -0.973613  0.999876  0.548792  0.502468
# 1122  Crying  0.521599  0.570071 -0.977505  0.999875  0.547507  0.492844
# 1123  Crying  0.521873  0.558028 -1.085793  0.999870  0.547365  0.481933
# 1124  Crying  0.521676  0.552647 -1.030313  0.999868  0.546823  0.472222
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
X_train
# Out:
#             x1        y1        z1        v1        x2        y2        z2  \
# 661   0.543576  0.627877 -0.525409  0.999988  0.556534  0.569039 -0.461420
# 398   0.546131  0.612814 -0.879648  0.999741  0.574578  0.523185 -0.849766
# 552   0.575728  0.593347 -1.243314  0.999667  0.598358  0.512452 -1.209062
# 159   0.548533  0.509627 -0.918403  0.999873  0.572820  0.445494 -0.865900
# 271   0.647030  0.585556 -1.258936  0.999381  0.663902  0.505298 -1.199699
# ...        ...       ...       ...       ...       ...       ...       ...
# 689   0.569349  0.481656 -0.853629  0.999991  0.587857  0.425613 -0.777840
# 664   0.540995  0.627591 -0.580996  0.999987  0.554954  0.568927 -0.519961
# 1077  0.535699  0.581970 -1.359129  0.999937  0.560746  0.508554 -1.283417
# 723   0.486957  0.529680 -0.686127  0.999982  0.509336  0.466993 -0.614409
# 815   0.496519  0.552822 -0.652308  0.999970  0.515712  0.489292 -0.579550
#
# ...

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
list(pipelines.values())[0]
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Victorious', 'Victorious', 'Crying', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Sad', 'Victorious', 'Victorious', 'Happy',
#        'Victorious', 'Crying', 'Sad', 'Victorious', 'Victorious', 'Happy',
#        'Happy', 'Victorious', 'Victorious', 'Sad', 'Sad', 'Victorious',
#        'Crying', 'Crying', 'Victorious', 'Crying', 'Victorious', 'Sad',
#        'Sad', 'Sad', 'Sad', 'Crying', 'Crying', 'Crying', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Victorious', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Victorious', 'Sad', 'Crying', 'Victorious', 'Happy', 'Happy',
#        'Crying', 'Happy', 'Happy', 'Victorious', 'Victorious', 'Crying',
#        'Sad', 'Happy', 'Victorious', 'Sad', 'Sad', 'Victorious', 'Crying',
#        'Happy', 'Happy', 'Crying', 'Happy', 'Crying', 'Victorious',
#        'Crying', 'Sad', 'Sad', 'Crying', 'Crying', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Happy', 'Sad', 'Victorious', 'Victorious',
# ...

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Victorious', 'Victorious', 'Crying', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Sad', 'Victorious', 'Victorious', 'Happy',
#        'Victorious', 'Crying', 'Sad', 'Victorious', 'Victorious', 'Happy',
#        'Happy', 'Victorious', 'Victorious', 'Sad', 'Sad', 'Victorious',
#        'Crying', 'Crying', 'Victorious', 'Crying', 'Victorious', 'Sad',
#        'Sad', 'Sad', 'Sad', 'Crying', 'Crying', 'Crying', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Victorious', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Victorious', 'Sad', 'Crying', 'Victorious', 'Happy', 'Happy',
#        'Crying', 'Happy', 'Happy', 'Victorious', 'Victorious', 'Crying',
#        'Sad', 'Happy', 'Victorious', 'Sad', 'Sad', 'Victorious', 'Crying',
#        'Happy', 'Happy', 'Crying', 'Happy', 'Crying', 'Victorious',
#        'Crying', 'Sad', 'Sad', 'Crying', 'Crying', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Happy', 'Sad', 'Victorious', 'Victorious',
# ...

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9940828402366864

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Victorious', 'Victorious', 'Crying', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Sad', 'Victorious', 'Victorious', 'Happy',
#        'Victorious', 'Crying', 'Sad', 'Victorious', 'Victorious', 'Happy',
#        'Happy', 'Victorious', 'Victorious', 'Sad', 'Sad', 'Victorious',
#        'Crying', 'Crying', 'Victorious', 'Crying', 'Victorious', 'Sad',
#        'Sad', 'Sad', 'Sad', 'Crying', 'Crying', 'Crying', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Victorious', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Victorious', 'Sad', 'Crying', 'Victorious', 'Happy', 'Happy',
#        'Crying', 'Happy', 'Happy', 'Victorious', 'Victorious', 'Crying',
#        'Sad', 'Happy', 'Victorious', 'Sad', 'Sad', 'Victorious', 'Crying',
#        'Happy', 'Happy', 'Crying', 'Happy', 'Crying', 'Victorious',
#        'Crying', 'Sad', 'Sad', 'Crying', 'Crying', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Happy', 'Sad', 'Victorious', 'Victorious',
# ...

# %%
y_test
# Out:
# 902     Victorious
# 867     Victorious
# 1056        Crying
# 888     Victorious
# 272            Sad
#            ...
# 387            Sad
# 328            Sad
# 535            Sad
# 892     Victorious
# 741     Victorious
# Name: class, Length: 338, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
print(len(row))
# Out:
# 2005

# %%
print(X.shape)
# Out:
# (1125, 2004)

# %%
print(model.classes_)
# Out:
# ['Crying' 'Happy' 'Sad' 'Victorious']

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))

# %%
import pandas as pd

df = pd.read_csv("coords.csv")  # แทนที่ด้วยไฟล์จริง
print("Number of features used in training:", df.shape[1] - 1)  # ลบ 1 เพราะคอลัมน์ label
# Out:
# Number of features used in training: 2004

# %%
# ตรวจสอบค่าที่ได้จากการทำนาย
body_language_class = model.predict(X)[0]
body_language_prob = model.predict_proba(X)[0]

# แสดงผล
print("Predicted Class:", body_language_class)
print("Prediction Probabilities:", body_language_prob)
# Out:
# Predicted Class: Happy
# Prediction Probabilities: [0. 1. 0. 0.]

# %%
# ตรวจสอบคลาสที่มีค่าความน่าจะเป็นสูงสุด
predicted_class = model.classes_[np.argmax(body_language_prob)]
print("Predicted Class with Highest Probability:", predicted_class)
# Out:
# Predicted Class with Highest Probability: Happy

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import pickle

mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_hands = mp.solutions.hands
mp_face_mesh = mp.solutions.face_mesh

# ใช้ Face Mesh สำหรับ Face Landmarks
FACE_CONNECTIONS = mp_face_mesh.FACEMESH_TESSELATION
HAND_CONNECTIONS = mp_hands.HAND_CONNECTIONS
POSE_CONNECTIONS = mp_holistic.POSE_CONNECTIONS

cap = cv2.VideoCapture(0)

# โหลดโมเดลที่ใช้ในการทำนาย
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

with mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5) as face_mesh, \
     mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        

        # ประมวลผล Holistic Model
        results = holistic.process(image)

        # ประมวลผล Face Mesh
        face_results = face_mesh.process(image)

        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # 1. Face landmarks (ใช้ Face Mesh โดยตรง)
        if face_results.multi_face_landmarks:
            for face_landmarks in face_results.multi_face_landmarks:
                mp_drawing.draw_landmarks(image, face_landmarks, FACE_CONNECTIONS, 
                                          mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                          mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1))

        # 2. Right Hand
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, HAND_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))

        # 3. Left Hand
        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, HAND_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))

        # 4. Pose Detections
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, POSE_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))
            
        #  Export coordinates to CSV
        try:
            # Extract pose  landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            # Extract face landmarks
            face = face_results.multi_face_landmarks[0].landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            # Concatenate the rows
            row = pose_row + face_row

            # Make prediction
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)

            # Grab ear coordinates
            coords = tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x,
                                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)),
                                        [640, 480]).astype(int))

            # Display prediction on screen
            cv2.rectangle(image, (coords[0], coords[1]+5), (coords[0] + len(body_language_class) * 20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
                                                
        except Exception as e:
            print("Error:", e)

        cv2.imshow('Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743309470.897397 5340774 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1743309470.910272 5341463 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1743309470.914872 5341463 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1743309470.922730 5340774 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1743309471.001099 5341466 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
